# %% [markdown]
# # Buffer Stock Model

# %%
import numpy as np
import matplotlib.pyplot as plt

# reload module each time cell is run
# %load_ext autoreload
# %autoreload 2

from consav import runtools
runtools.write_numba_config(disable=0,threads=8)

# load the BufferStockModel module
from MPCF import MPCFClass
import figs

# %% [markdown]
# # Setup

# %%
LOAD = True
LOAD_PERS = True
LOAD_RHO = True
LOAD_BETA = True
LOAD_ANNUAL = True
LOAD_CARROLL = True

# %% [markdown]
# # Baseline

# %%
# a. setup
model = MPCFClass(name='baseline',load=LOAD,zeta=1)

if not LOAD:

    # b. solve
    model.solve()

    # c. save
    model.save()

# %% [markdown]
# ## Figures

# %%
figs.cfunc(model,savefig=True)

# %%
figs.MPC(model,savefig=True)

# %%
figs.MPCF(model,savefig=True)

# %% [markdown]
# **For comparison in appendix:**

# %%
fig,ax = figs._MPCF(model,taus=[1,4,12],show_theoretical=True)
ax.set_xlim([0,12])

fig.tight_layout()
fig.savefig('figs/MPCF_compare.pdf')

# %% [markdown]
# **Simulation:**

# %%
figs.simulate(model,savefig=True)

# %% [markdown]
# # Varying $\zeta$

# %%
def model_loop(basename,key,vals,basemodel,LOAD,taus=[1,4,12]):
    
    models = []
    for i,value in enumerate(vals):
    
        print(f'{key} = {value}\n')
          
        par = {key:value}
    
        # a. setup
        models.append(MPCFClass(name=f'{basename}{i}',load=LOAD,**par))

        if not LOAD:

            # b. solve
            if i == 0:
                models[i].solve_with_c0(basemodel.sol.c[0,:,:])
            else:
                models[i].solve_with_c0(models[i-1].sol.c[0,:,:])

            # c. save
            models[i].save()
        
        # d. figures
        postfix=f'_{basename}{i}'
        figs.MPCF(models[i],taus=taus,show_theoretical=True,postfix=postfix,savefig=True)
        figs.simulate(models[i],postfix=postfix,savefig=True)
        
        plt.show()
        print('')

# %%
zetas = [0.99**(1/12),0.95**(1/12),0.90**(1/12),0.80**(1/12)]
model_loop('pers','zeta',zetas,model,LOAD_PERS)
# Out:
# zeta = 0.9991628226408794
# zeta = 0.9957346812224394
# zeta = 0.9912583890453033
# zeta = 0.9815765298737517

# %% [markdown]
# # Varying $\rho$

# %%
rhos = [1.5,3,4]
model_loop('rho','rho',rhos,model,LOAD_RHO)
# Out:
# rho = 1.5
# rho = 3
# rho = 4

# %%
betas = [0.95**(1/12),0.94**(1/12),0.93**(1/12)]
model_loop('beta','beta',betas,model,LOAD_BETA)
# Out:
# beta = 0.9957346812224394
# beta = 0.994856987168177
# beta = 0.9939706919338731

# %% [markdown]
# # Annual

# %%
# a. setup
par = {}
par['beta'] = 0.96
par['R'] = 1.04
par['G'] = 1.03
par['sigma_psi'] = np.sqrt(0.0054)
par['sigma_xi'] = np.sqrt(0.0072)

par['Ndelta'] = 50
par['Nm'] = 10_000
par['m_mid'] = 10
par['m_max'] = 10_000
par['Na'] = 5_000
par['a_mid'] = par['m_mid']
par['a_max'] = par['m_max']

model_annual = MPCFClass(name='annual',load=LOAD_ANNUAL,**par)

if not LOAD_ANNUAL:

    # b. solve
    model_annual.solve()

    # c. save
    model_annual.save()
    
    print('')

# d. figures
postfix = '_annual'
figs.cfunc(model_annual,m_max=5,c_max=2,postfix=postfix,savefig=True)
figs.MPC(model_annual,m_max=5,postfix=postfix,savefig=True)
figs.MPCF(model_annual,m_max=5,taus=[0,1,2,4],postfix=postfix,savefig=True)
